# %%
# 1.6. Wczytywanie i prezentowanie danych
# Wybierz dwie dowolne kolumny (z wyjątkiem pierwszej) z pliku data2.csv. 
# Przedstaw zależność między tymi danymi na wykresie punktowym
# (wartości z jednej kolumny powinny znaleźć się na jednej osi, a wartości z drugiej kolumny – na drugiej osi).

# Uwaga: plik z danymi należy zapisać u siebie na dysku - przyjmijmy, że znajduje się on w tym samym katalogu, co skrypt.

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# Read CSV data from file
data = pd.read_csv('data2.csv', header=None)
data_array = data.to_numpy()

# Select data
x = data_array[:, 4]
y = data_array[:, 6]


# Create plot with matplotlib
plt.plot(x, y, 'bo')

plt.show()  # Show plot
